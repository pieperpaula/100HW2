# %% [markdown]
# ###### 1.00/1.001 Engineering Computation and Data Science
# # Problem Set 2
# #### Due before March 3rd 2021 11:59 PM

# %%
# Useful Relevant Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Boilerplate Answer Declaration
your_answer_here = '{{replace this variable with the your own statement for the correct code. }}'

# If you feel you need to import additional libraries,
# you can do so in the relevant question

# %% [markdown]
# ## 2.1) What day of the week was 1/1/1970

# %%
myArray = np.array([1,2,3,4,5,6,7])
mySeries = pd.Series(myArray)
mySeries.index = pd.date_range(start='1/1/1970', periods=7)
mySeries.index.dayofweek
#Monday = 0...

# Your Code Goes Here
weekdays = mySeries.index.day_name()
your_answer_here = weekdays[0]

print ("January 1st 1970 was a", your_answer_here)
# Out:
# January 1st 1970 was a Thursday

# %% [markdown]
# ## 2.2) UFO Data Analysis

# %%
# let's import the ufo data from the online collection
ufo = pd.read_csv('http://bit.ly/uforeports', parse_dates=['Time'])

# and get a preview of the data we're working with
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %% [markdown]
# ### 2.2.1) What day of the week has the most sightings?

# %%
# Your Code Goes Here
ufo ["Day"]= ufo["Time"].dt.day_name()
weekday_count = ufo["Day"].value_counts()
your_answer_here = weekday_count.index[0]
print("The most popular day of the week to report a UFO was", your_answer_here)
# Out:
# The most popular day of the week to report a UFO was Tuesday

# %% [markdown]
# ### 2.2.2) On the day of the week with most sightings plot a histogram the time of day the sightings occured
# Give the slight confusion on the earlier version of this question; we will accept a plot for the day of the week (*e.g. Saturday, Sunday, etc.*) with the most UFO sightings OR the calendar date (*e.g. January 19 2001, November 3 1989*) with the most UFO sightings.

# %%
ufo_tuesday = ufo.loc[ufo["Day"] == "Tuesday"]
ufo_tuesday['time of day']= ufo_tuesday['Time'].apply( lambda d : d.time() )
# Out:
# /Users/paulapieper/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import matplotlib.pyplot as plt 
tuesday_times = plt.hist(x = ufo_tuesday["time of day"], bins = 30)

# %% [markdown]
# ### 2.2.3) Do the same for the calendar date with the 2nd most sightings

# %%
second_day = weekday_count.index[1]
print("The most popular day of the week to report a UFO was", second_day)
# Out:
# The most popular day of the week to report a UFO was Sunday

# %%
ufo_sunday = ufo.loc[ufo["Day"] == "Sunday"]
ufo_sunday['time of day']= ufo_sunday['Time'].apply( lambda d : d.time() )
# Out:
# /Users/paulapieper/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sunday_times = plt.hist(x = ufo_sunday["time of day"], bins = 30)

# %% [markdown]
# ### 2.2.4) For extra credit - Are there any deductions or patterns you see in the data? Justify with plots or data.
# One possible idea here, is to answer the opposite question you answered in 2.2.2. (*e.g. if you answered day of week then do calendar date here*); however, we will accept any observations you make here provided you substantiate them with data analysis.
#
# Below I have plotted the rest of the weekday sitings. All the histograms show similar trends in terms of peaks when sitings happened. They are typically in the dark hours of the day. I think this could be because of two hypotheses. One is that I believe more people look at the sky when it is dark outside. The second is that lights in the sky that may be coming from a UFO are more noticeable against the darker sky at night.

# %%
ufo_wed = ufo.loc[ufo["Day"] == "Wednesday"]
ufo_wed['time of day']= ufo_wed['Time'].apply( lambda d : d.time() )

ufo_mon = ufo.loc[ufo["Day"] == "Monday"]
ufo_mon['time of day']= ufo_mon['Time'].apply( lambda d : d.time() )

ufo_sat = ufo.loc[ufo["Day"] == "Saturday"]
ufo_sat['time of day']= ufo_sat['Time'].apply( lambda d : d.time() )

ufo_thurs = ufo.loc[ufo["Day"] == "Thursday"]
ufo_thurs['time of day']= ufo_thurs['Time'].apply( lambda d : d.time() )

ufo_fri = ufo.loc[ufo["Day"] == "Friday"]
ufo_fri['time of day']= ufo_fri['Time'].apply( lambda d : d.time() )
# Out:
# /Users/paulapieper/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/paulapieper/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/paulapieper/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
wed_times = plt.hist(x = ufo_wed["time of day"], bins = 30)

# %%
fri_times = plt.hist(x = ufo_fri["time of day"], bins = 30)

# %%
sat_times = plt.hist(x = ufo_sat["time of day"], bins = 30)

# %%
mon_times = plt.hist(x = ufo_mon["time of day"], bins = 30)

# %%
thurs_times = plt.hist(x = ufo_thurs["time of day"], bins = 30)
